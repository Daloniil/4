# %% [markdown]
# Індивідуальне завдання №1
# Створити вкладену структуру даних представлення інформації працівника провідної компанії: прізвище, ім'я, по батькові, вік, університет, департамент, відділ, посада, заробітна плата, електронна адреса, номер телефону. При створенні вкладеної структури даних можна використовувати будь-які комбінації вивчених об'єктів (списки, кортежи, словники, рядки, числа ...).

# %%
worker = {
    'surname' : "Petrov",
    'name' : "Petr",
    'partromic' : "Petrovich",
    'age' : "18",
    'university' : "KNU",
    'department' : "Developer",
    'post': "Back-end Developer",
    'salary' : 1500,
    'email' : 'helloi@yahoo.com',
    'phone' : '+380-344-34-44'
}

# %% [markdown]
# Індивідуальне завдання №2
# Роздрукувати поля вкладеної структури даних (Індивідуального завдання №1) на кожному окремому рядку у зворотньому порядку. Чи є переваги обраних об'єктів у порівнянні з іншими для створення вкладеної структури даних

# %%
worker = {
    'surname' : "Petrov",
    'name' : "Petr",
    'partromic' : "Petrovich",
    'age' : "18",
    'university' : "KNU",
    'department' : "Developer",
    'post': "Back-end Developer",
    'salary' : 1500,
    'email' : 'helloi@yahoo.com',
    'phone' : '+380-344-34-44'
}
for i in reversed(list(worker.values())):
    print(i, "",  end = '')
# Out:
# +380-344-34-44 helloi@yahoo.com 1500 Back-end Developer Developer KNU 18 Petrovich Petr Petrov

# %% [markdown]
# Індивідуальне завдання №3
# Замінити поля вкладеної структури даних: департамент, відділ, посада, заробітна плата, електронна адреса, номер телефону на нові значення. Роздрукувати поля у прямому порядку.

# %%
worker = {
    'surname' : "Petrov",
    'name' : "Petr",
    'partromic' : "Petrovich",
    'age' : "18",
    'university' : "KNU",
    'department' : "Developer",
    'post': "Back-end Developer",
    'salary' : 1500,
    'email' : 'helloi@yahoo.com',
    'phone' : '+380-344-34-44'
}

worker['surname'] = 'Misha'
worker['name'] = 'Mishka'
worker['partromic'] ='Mishany'
worker['age'] = 122
worker['university'] = 'KNUKIM'
worker['department'] = ' Back'
worker['post'] = ' DEv'
worker['salary'] = 200000
worker['email'] = '@gmail.com'
worker['phone'] = "09777777"
for i in reversed(list(worker.values())):
    print(i, "",  end = '')
# Out:
# 09777777 @gmail.com 200000  DEv  Back KNUKIM 122 Mishany Mishka Misha

# %% [markdown]
# Індивідуальне завдання №4
# Написати сценарій, який створює і відкриває для запису новий файл з назвою empl.txt. До файлу записуються всі поля оновленої вкладеної структури даних. Представити зміст файлу.

# %%
worker = {
    'surname' : "Petrov",
    'name' : "Petr",
    'partromic' : "Petrovich",
    'age' : "18",
    'university' : "KNU",
    'department' : "Developer",
    'post': "Back-end Developer",
    'salary' : 1500,
    'email' : 'helloi@yahoo.com',
    'phone' : '+380-344-34-44'
}

worker['surname'] = 'Misha'
worker['name'] = 'Mishka'
worker['partromic'] ='Mishany'
worker['age'] = '122'
worker['university'] = 'KNUKIM'
worker['department'] = ' Back'
worker['post'] = ' DEv'
worker['salary'] = '200000'
worker['email'] = '@gmail.com'
worker['phone'] = "09777777"
for i in reversed(list(worker.values())):
 f = open('empl.txt', 'w')
for value in worker.values():
    f.write(value + " ")
f = open('empl.txt', 'r')
f.readline()
# Out:
# 'Misha Mishka Mishany 122 KNUKIM  Back  DEv 200000 @gmail.com 09777777 '

# %% [markdown]
# Індивідуальне завдання №5
# Написати сценарій, який відкриває файл empl.txt, читає його і виводить його зміст - всі поля на кожному рядку окремо

# %%
worker = {
    'surname' : "Petrov",
    'name' : "Petr",
    'partromic' : "Petrovich",
    'age' : "18",
    'university' : "KNU",
    'department' : "Developer",
    'post': "Back-end Developer",
    'salary' : '1500',
    'email' : 'helloi@yahoo.com',
    'phone' : '+380-344-34-44'
}

worker['surname'] = 'Misha'
worker['name'] = 'Mishka'
worker['partromic'] ='Mishany'
worker['age'] = '122'
worker['university'] = 'KNUKIM'
worker['department'] = ' Back'
worker['post'] = ' DEv'
worker['salary'] = '200000'
worker['email'] = '@gmail.com'
worker['phone'] = "09777777"

for i in reversed(list(worker.values())):
 f = open('empl.txt', 'w')
for value in worker.values():
    f.write(value + " ")
with open('empl.txt', 'r') as f:
    for line in f:
        for word in line.split():
            print(word)
# Out:
# Misha
# Mishka
# Mishany
# 122
# KNUKIM
# Back
# DEv
# 200000
# @gmail.com
# 09777777

# %% [markdown]
# Індивідуальне завдання №6
# Повернути старі значення вкладеної структури даних, які були оновлені в Індиідуальному завданні №3, шляхом виконання команд заміни.
# Оновити файл empl.txt зміненим змістом вкладеної структури даних, тобто зі старими даними полів. Роздрукувати оновлений зміст файлу empl.txt.

# %%
worker = {
    'surname' : "Petrov",
    'name' : "Petr",
    'partromic' : "Petrovich",
    'age' : "18",
    'university' : "KNU",
    'department' : "Developer",
    'post': "Back-end Developer",
    'salary' : '1500',
    'email' : 'helloi@yahoo.com',
    'phone' : '+380-344-34-44'
}

worker['surname'] = 'Misha'
worker['name'] = 'Mishka'
worker['partromic'] ='Mishany'
worker['age'] = '122'
worker['university'] = 'KNUKIM'
worker['department'] = ' Back'
worker['post'] = ' DEv'
worker['salary'] = '200000'
worker['email'] = '@gmail.com'
worker['phone'] = "09777777"
for i in reversed(list(worker.values())):
 f = open('empl.txt', 'w')
for value in worker.values():
    f.write(value + " ")
worker['surname'] = 'Petrov'
worker['name'] = 'Petr'
worker['partromic'] ='Petrovich'
worker['age'] = '18'
worker['university'] = 'KNU'
worker['department'] = ' Developer'
worker['post'] = ' Back-end Developer'
worker['salary'] = '1500'
worker['email'] = '@helloi@yahoo.com'
worker['phone'] = "+380-344-34-44"
for s in reversed(list(worker.values())):
    f = open('empl.txt', 'w')
for value in worker.values():
    f.write(value + " ")
with open('empl.txt', 'r') as f:
    for line in f:
        for word in line.split():
            print(word)
# Out:
# Petrov
# Petr
# Petrovich
# 18
# KNU
# Developer
# Back-end
# Developer
# 1500
# @helloi@yahoo.com
# +380-344-34-44
